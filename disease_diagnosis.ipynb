# %%
print("AI DIAGNOSIS ACTIVATED")
print("answer with simple yes and no")
fever = input("Do you have fever? ")
cough = input("Do you have cough? ")
headache = input("do you have headache? ")
fatigue = input("do you have fatigue ? ")
vomit = input("do you have vomiting? ")
chest = input("Do you have chest pain? ")
breath = input("Do you have breathing difficulty ? ")
body = input("Do you have body pain? ")
thirst = input("Do you have excessive thirst? ")
urine = input("Do you have frequent urination? ")

print("Analying symptoms...")

if fever == "yes" and cough == "no" and headache == "yes" and fatigue == "yes" and vomit == "no" and chest == "no" and breath == "no" and body == "yes" and thirst == "no" and urine == "no":
  print("you have flu")
  print("Severity: MODERATE")
elif fever == "yes" and cough == "yes" and headache == "no" and fatigue == "no" and vomit == "no" and chest == "no" and breath == "no" and body == "no" and thirst == "no" and urine == "no":
  print("You have common cold")
  print("severity: MILD")
elif  fever == "yes" and cough == "no" and headache == "yes" and fatigue == "yes" and vomit == "yes" and chest == "no" and breath == "no" and body == "no" and thirst == "no" and urine == "no":
  print("You have food poisoning")
  print("severity: MODERATE")
elif fever == "no" and cough == "no" and headache == "yes"  and fatigue == "no" and vomit == "no" and chest == "no" and breath == "no" and body == "no" and thirst == "no" and urine == "no":
  print("You got migraine")
  print("severity: MILD/MODERATE")
elif fever == "no" and cough == "no" and headache == "no" and fatigue == "no" and vomit == "no" and chest == "no" and breath == "no" and body == "yes" and thirst == "yes" and urine == "no":
  print("You have a risk of diabetes")
  print("severity: MODERATE")
elif fever == "yes" and cough == "yes" and headache == "no" and fatigue == "yes" and vomit == "yes" and chest == "no" and breath == "yes" and body == "no" and thirst == "no" and urine == "no":
 print("You have covid 19")
 print("severity: SEVERE")
elif fever == "no" and cough == "no" and headache == "no"  and fatigue == "no" and vomit == "no" and chest == "yes" and breath == "yes" and body == "no" and thirst == "no" and urine == "no":
  print("You have heart related risk")
  print("severity: SEVERE")
else:
  print("Incorrect input")
# Out:
# AI DIAGNOSIS ACTIVATED
# answer with simple yes and no
# Do you have fever? yes
# Do you have cough? yes
# do you have headache? no
# do you have fatigue ? yes
# do you have vomiting? yes
# Do you have chest pain? no
# Do you have breathing difficulty ? yes
# Do you have body pain? no
# Do you have excessive thirst? no
# Do you have frequent urination? no
# Analying symptoms...
# You have covid 19
# severity: SEVERE
